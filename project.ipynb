# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.cluster import SpectralClustering
from sklearn.decomposition import TruncatedSVD

# %%
df = pd.read_csv('abstractdata5.csv', sep='#', names=['id', 'class', 'title', 'abstract'])
df
# Out:
#           id  class                                              title  \
# 0        id1      1  Anomaly detection in wide area imagery [Geniş ...
# 1        id2      1  Person re-identification with deep kronecker-p...
# 2        id3      1    Crack detection in images of masonry using cnns
# 3        id4      5  Towards an energy efficient code generator for...
# 4        id5      5  Sub-polyhedral scheduling using (Unit-)two-var...
# ...      ...    ...                                                ...
# 1327  id1328      1  Colorimetric point-of-care paper-based sensors...
# 1328  id1329      1  Calcium identification and scoring based on ec...
# 1329  id1330      1  Considering filter importance and irreplaceabi...
# 1330  id1331      4  Low-complexity bit-serial sequential polynomia...
# 1331  id1332      5  Preventing reverse engineering threat in java ...
#
#                                                abstract
# 0     This study is about detecting anomalies in wid...
# 1     Person re-identification (re-ID) aims to robus...
# 2     While there is a significant body of research ...
# 3     Using a smartphone become the part of our ever...
# 4     Polyhedral compilation has been successful in ...
# ...                                                 ...
# 1327  Creatinine is a clinically significant analyte...
# 1328  Currently, an echocardiography expert is neede...
# 1329  Deep convolutional neural network (CNNs) have ...
# 1330  GF(2m) multiplication is a complex and perform...
# 1331  Java programs are compiled into a platform ind...
#
# [1332 rows x 4 columns]

# %% [markdown]
# source for punctuation removal: https://stackoverflow.com/questions/39782418/remove-punctuations-in-pandas
# source for stopword removal:
# https://stackoverflow.com/questions/29523254/python-remove-stop-words-from-pandas-dataframe

# %%
def countAndSort(cluster):
  v = CountVectorizer()
  x = v.fit_transform(cluster)

  counts = x.toarray().sum(axis=0)
  features = v.get_feature_names_out()

  d = dict(zip(features, counts))
  sortedByCount = sorted(d.items(), key=lambda x: x[1], reverse=True)
  
  return sortedByCount


# Remove punctuation
df['joined'] = df['title'] + df['abstract']
df['noPunct'] = df['joined'].str.replace('[^\w\s]','')

# Remove digits
df['noPunct'] = df['noPunct'].str.replace('\d+', '')

# Remove unicode
df['noPunct'].str.encode('ascii', 'ignore').str.decode('ascii')

# Lowercase
df['noPunct'] = df['noPunct'].str.lower()

# Remove stopwords
stop = stopwords.words('english')
df['noStopwords'] = df['noPunct'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
# Out:
# /tmp/ipykernel_634/3245601538.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['noPunct'] = df['joined'].str.replace('[^\w\s]','')
# /tmp/ipykernel_634/3245601538.py:19: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['noPunct'] = df['noPunct'].str.replace('\d+', '')

# %%
a = countAndSort(df['noStopwords'])
a
# Out:
# [('data', 1385),
#  ('using', 939),
#  ('proposed', 840),
#  ('system', 834),
#  ('based', 794),
#  ('model', 687),
#  ('paper', 683),
#  ('results', 594),
#  ('method', 590),
#  ('used', 563),
#  ('performance', 562),
#  ('information', 537),
#  ('systems', 532),
#  ('approach', 527),
#  ('learning', 483),
#  ('security', 474),
#  ('algorithm', 471),
#  ('database', 469),
#  ('different', 440),
#  ('also', 435),
#  ('image', 423),
#  ('analysis', 420),
#  ('design', 409),
#  ('time', 406),
#  ('detection', 399),
#  ('methods', 393),
#  ('new', 391),
#  ('compiler', 388),
#  ('use', 379),
#  ('two', 372),
#  ('applications', 371),
#  ('computer', 367),
#  ('network', 360),
#  ('show', 351),
#  ('however', 341),
#  ('key', 341),
#  ('work', 331),
#  ('quantum', 330),
#  ('images', 329),
#  ('vision', 329),
#  ('research', 328),
#  ('study', 320),
#  ('control', 318),
#  ('relational', 315),
#  ('algorithms', 312),
#  ('process', 304),
#  ('framework', 302),
#  ('one', 293),
#  ('problem', 285),
#  ('present', 279),
#  ('techniques', 278),
#  ('scheme', 276),
#  ('accuracy', 272),
#  ('code', 266),
#  ('models', 262),
#  ('propose', 262),
#  ('robot', 259),
#  ('number', 255),
#  ('efficient', 253),
#  ('application', 250),
#  ('deep', 246),
#  ('existing', 241),
#  ('encryption', 240),
#  ('robots', 239),
#  ('compared', 233),
#  ('visual', 232),
#  ('high', 231),
#  ('cryptography', 230),
#  ('first', 230),
#  ('language', 228),
#  ('novel', 226),
#  ('set', 225),
#  ('development', 224),
#  ('implementation', 224),
#  ('secure', 223),
#  ('databases', 218),
#  ('features', 213),
#  ('provide', 212),
#  ('many', 210),
#  ('training', 207),
#  ('technique', 206),
#  ('neural', 205),
#  ('architecture', 203),
#  ('technology', 201),
#  ('various', 200),
#  ('memory', 195),
#  ('large', 192),
#  ('software', 189),
#  ('multiple', 185),
#  ('developed', 184),
#  ('object', 184),
#  ('due', 182),
#  ('robotic', 182),
#  ('important', 181),
#  ('dataset', 180),
#  ('experiments', 179),
#  ('cloud', 178),
#  ('processing', 178),
#  ('tasks', 177),
#  ('experimental', 176),
#  ('well', 176),
#  ('hardware', 175),
#  ('communication', 174),
#  ('improve', 173),
#  ('computing', 172),
#  ('approaches', 170),
#  ('graph', 170),
#  ('tracking', 170),
#  ('without', 170),
#  ('evaluation', 169),
#  ('order', 169),
#  ('networks', 168),
#  ('machine', 167),
#  ('optimization', 167),
#  ('three', 167),
#  ('better', 166),
#  ('structure', 166),
#  ('environment', 164),
#  ('field', 164),
#  ('may', 163),
#  ('program', 163),
#  ('task', 163),
#  ('dynamic', 162),
#  ('several', 159),
#  ('feature', 158),
#  ('human', 158),
#  ('protocol', 155),
#  ('query', 155),
#  ('attacks', 154),
#  ('complex', 154),
#  ('computation', 154),
#  ('provides', 152),
#  ('construction', 150),
#  ('programming', 150),
#  ('implemented', 149),
#  ('test', 147),
#  ('presents', 146),
#  ('devices', 145),
#  ('iot', 145),
#  ('recognition', 145),
#  ('video', 145),
#  ('user', 144),
#  ('current', 143),
#  ('power', 142),
#  ('presented', 141),
#  ('recent', 140),
#  ('users', 140),
#  ('knowledge', 139),
#  ('programs', 139),
#  ('storage', 139),
#  ('management', 138),
#  ('quality', 137),
#  ('support', 137),
#  ('tool', 137),
#  ('case', 136),
#  ('future', 136),
#  ('demonstrate', 135),
#  ('execution', 135),
#  ('solution', 135),
#  ('theory', 135),
#  ('classification', 134),
#  ('schemes', 134),
#  ('speed', 134),
#  ('traditional', 134),
#  ('designed', 133),
#  ('estimation', 133),
#  ('finally', 133),
#  ('objects', 132),
#  ('area', 131),
#  ('performed', 131),
#  ('article', 130),
#  ('including', 130),
#  ('obtained', 130),
#  ('size', 129),
#  ('level', 128),
#  ('applied', 127),
#  ('segmentation', 127),
#  ('problems', 126),
#  ('standard', 126),
#  ('input', 125),
#  ('parameters', 125),
#  ('complexity', 124),
#  ('achieve', 123),
#  ('challenges', 123),
#  ('improved', 123),
#  ('operations', 122),
#  ('energy', 121),
#  ('technologies', 121),
#  ('type', 121),
#  ('cost', 120),
#  ('available', 119),
#  ('cryptographic', 119),
#  ('terms', 119),
#  ('therefore', 119),
#  ('way', 119),
#  ('potential', 118),
#  ('efficiency', 117),
#  ('need', 117),
#  ('computational', 115),
#  ('space', 115),
#  ('stateoftheart', 115),
#  ('target', 115),
#  ('within', 115),
#  ('automated', 114),
#  ('generated', 114),
#  ('realtime', 114),
#  ('state', 114),
#  ('semantic', 113),
#  ('soft', 113),
#  ('domain', 112),
#  ('evaluate', 112),
#  ('thus', 112),
#  ('allows', 111),
#  ('authentication', 111),
#  ('average', 111),
#  ('main', 111),
#  ('function', 110),
#  ('monitoring', 110),
#  ('motion', 110),
#  ('reduce', 110),
#  ('small', 110),
#  ('access', 109),
#  ('datasets', 109),
#  ('environments', 109),
#  ('single', 109),
#  ('flow', 107),
#  ('robotics', 107),
#  ('source', 107),
#  ('tools', 107),
#  ('error', 106),
#  ('mapping', 106),
#  ('privacy', 106),
#  ('types', 106),
#  ('could', 105),
#  ('point', 105),
#  ('significant', 105),
#  ('low', 104),
#  ('required', 104),
#  ('automatic', 103),
#  ('measurement', 103),
#  ('queries', 103),
#  ('result', 103),
#  ('able', 102),
#  ('autonomous', 101),
#  ('studies', 101),
#  ('given', 100),
#  ('convolutional', 99),
#  ('transformation', 99),
#  ('addition', 98),
#  ('camera', 98),
#  ('possible', 98),
#  ('proposes', 98),
#  ('specific', 98),
#  ('generation', 97),
#  ('health', 97),
#  ('parallel', 97),
#  ('real', 97),
#  ('best', 96),
#  ('conditions', 96),
#  ('increase', 96),
#  ('moreover', 96),
#  ('since', 96),
#  ('even', 95),
#  ('map', 95),
#  ('perform', 95),
#  ('search', 95),
#  ('digital', 94),
#  ('effective', 94),
#  ('hybrid', 93),
#  ('often', 93),
#  ('related', 93),
#  ('strategy', 93),
#  ('identification', 92),
#  ('operation', 92),
#  ('protocols', 92),
#  ('sensor', 92),
#  ('simple', 92),
#  ('sql', 92),
#  ('ability', 91),
#  ('address', 91),
#  ('make', 91),
#  ('value', 91),
#  ('languages', 90),
#  ('register', 90),
#  ('shows', 90),
#  ('behavior', 89),
#  ('evaluated', 89),
#  ('like', 89),
#  ('platform', 89),
#  ('representation', 89),
#  ('simulation', 89),
#  ('challenging', 88),
#  ('comparison', 88),
#  ('conventional', 88),
#  ('develop', 88),
#  ('furthermore', 88),
#  ('previous', 88),
#  ('public', 88),
#  ('random', 88),
#  ('review', 88),
#  ('sensors', 88),
#  ('achieved', 87),
#  ('mobile', 87),
#  ('significantly', 87),
#  ('optimal', 86),
#  ('safety', 86),
#  ('smart', 86),
#  ('solutions', 86),
#  ('functions', 85),
#  ('linear', 85),
#  ('patients', 85),
#  ('phase', 85),
#  ('rate', 85),
#  ('requirements', 85),
#  ('fast', 84),
#  ('increasing', 84),
#  ('part', 84),
#  ('students', 84),
#  ('suitable', 84),
#  ('attention', 83),
#  ('automatically', 83),
#  ('effectiveness', 83),
#  ('embedded', 83),
#  ('ie', 83),
#  ('loop', 83),
#  ('vehicle', 83),
#  ('uses', 82),
#  ('via', 82),
#  ('gait', 81),
#  ('higher', 81),
#  ('literature', 81),
#  ('module', 81),
#  ('online', 81),
#  ('surface', 81),
#  ('accurate', 80),
#  ('attack', 80),
#  ('introduced', 80),
#  ('mechanism', 80),
#  ('physical', 80),
#  ('practical', 80),
#  ('range', 80),
#  ('spatial', 80),
#  ('called', 79),
#  ('copyright', 79),
#  ('fully', 79),
#  ('years', 79),
#  ('conducted', 78),
#  ('eg', 78),
#  ('secret', 78),
#  ('structures', 78),
#  ('architectures', 77),
#  ('constraints', 77),
#  ('general', 77),
#  ('hand', 77),
#  ('help', 77),
#  ('lightweight', 77),
#  ('local', 77),
#  ('must', 77),
#  ('second', 77),
#  ('chaotic', 76),
#  ('errors', 76),
#  ('good', 76),
#  ('major', 76),
#  ('properties', 76),
#  ('requires', 76),
#  ('robustness', 76),
#  ('sensing', 76),
#  ('strategies', 76),
#  ('artificial', 75),
#  ('common', 75),
#  ('context', 75),
#  ('distribution', 75),
#  ('group', 75),
#  ('highly', 75),
#  ('still', 75),
#  ('towards', 75),
#  ('characteristics', 74),
#  ('internet', 74),
#  ('issues', 74),
#  ('less', 74),
#  ('reduced', 74),
#  ('respectively', 74),
#  ('identify', 73),
#  ('optimized', 73),
#  ('require', 73),
#  ('testing', 73),
#  ('associated', 72),
#  ('become', 72),
#  ('effect', 72),
#  ('filter', 72),
#  ('introduce', 72),
#  ('matching', 72),
#  ('modeling', 72),
#  ('feedback', 71),
#  ('force', 71),
#  ('improvement', 71),
#  ('limited', 71),
#  ('mean', 71),
#  ('robust', 71),
#  ('tested', 71),
#  ('assessment', 70),
#  ('clinical', 70),
#  ('detect', 70),
#  ('generate', 70),
#  ('integration', 70),
#  ('shape', 70),
#  ('shown', 70),
#  ('transfer', 70),
#  ('considered', 69),
#  ('industrial', 69),
#  ('providing', 69),
#  ('rules', 69),
#  ('among', 68),
#  ('building', 68),
#  ('consumption', 68),
#  ('found', 68),
#  ('functional', 68),
#  ('integrated', 68),
#  ('overhead', 68),
#  ('provided', 68),
#  ('remote', 68),
#  ('essential', 67),
#  ('four', 67),
#  ('promising', 67),
#  ('resources', 67),
#  ('similar', 67),
#  ('traffic', 67),
#  ('vehicles', 67),
#  ('web', 67),
#  ('according', 66),
#  ('achieves', 66),
#  ('color', 66),
#  ('demonstrated', 66),
#  ('distributed', 66),
#  ('especially', 66),
#  ('logic', 66),
#  ('metrics', 66),
#  ('ontology', 66),
#  ('open', 66),
#  ('reduction', 66),
#  ('role', 66),
#  ('challenge', 65),
#  ('compilers', 65),
#  ('graphs', 65),
#  ('implement', 65),
#  ('made', 65),
#  ('manual', 65),
#  ('solve', 65),
#  ('allocation', 64),
#  ('engineering', 64),
#  ('form', 64),
#  ('interaction', 64),
#  ('scenarios', 64),
#  ('structural', 64),
#  ('components', 63),
#  ('device', 63),
#  ('effects', 63),
#  ('efficiently', 63),
#  ('fuzzy', 63),
#  ('increased', 63),
#  ('natural', 63),
#  ('particular', 63),
#  ('precision', 63),
#  ('prediction', 63),
#  ('services', 63),
#  ('capabilities', 62),
#  ('class', 62),
#  ('combination', 62),
#  ('create', 62),
#  ('much', 62),
#  ('processors', 62),
#  ('scale', 62),
#  ('semantics', 62),
#  ('across', 61),
#  ('additional', 61),
#  ('difficult', 61),
#  ('heterogeneous', 61),
#  ('methodology', 61),
#  ('optical', 61),
#  ('resulting', 61),
#  ('stroke', 61),
#  ('surgical', 61),
#  ('along', 60),
#  ('example', 60),
#  ('fusion', 60),
#  ('inspection', 60),
#  ('integrity', 60),
#  ('known', 60),
#  ('navigation', 60),
#  ('necessary', 60),
#  ('processor', 60),
#  ('selection', 60),
#  ('works', 60),
#  ('world', 60),
#  ('big', 59),
#  ('comprehensive', 59),
#  ('healthcare', 59),
#  ('improving', 59),
#  ('making', 59),
#  ('nonlinear', 59),
#  ('obtain', 59),
#  ('overall', 59),
#  ('participants', 59),
#  ('social', 59),
#  ('validation', 59),
#  ('verification', 59),
#  ('analyzed', 58),
#  ('cases', 58),
#  ('file', 58),
#  ('goal', 58),
#  ('implementations', 58),
#  ('intelligent', 58),
#  ('original', 58),
#  ('scheduling', 58),
#  ('showed', 58),
#  ('understanding', 58),
#  ('values', 58),
#  ('visionbased', 58),
#  ('widely', 58),
#  ('bit', 57),
#  ('changes', 57),
#  ('describe', 57),
#  ('estimate', 57),
#  ('find', 57),
#  ('formal', 57),
#  ('interface', 57),
#  ('letter', 57),
#  ('makes', 57),
#  ('maps', 57),
#  ('patterns', 57),
#  ('times', 57),
#  ('videos', 57),
#  ('body', 56),
#  ('compilation', 56),
#  ('curve', 56),
#  ('depth', 56),
#  ('discuss', 56),
#  ('experiment', 56),
#  ('focus', 56),
#  ('individual', 56),
#  ('loss', 56),
#  ('measure', 56),
#  ('medical', 56),
#  ('needs', 56),
#  ('people', 56),
#  ('pose', 56),
#  ('practice', 56),
#  ('reducing', 56),
#  ('schema', 56),
#  ('advantages', 55),
#  ('concept', 55),
#  ('flexible', 55),
#  ('fpga', 55),
#  ('global', 55),
#  ('protection', 55),
#  ('response', 55),
#  ('samples', 55),
#  ('transformations', 55),
#  ('useful', 55),
#  ('view', 55),
#  ('circuit', 54),
#  ('cnn', 54),
#  ('distance', 54),
#  ('edge', 54),
#  ('enables', 54),
#  ('levels', 54),
#  ('recently', 54),
#  ('areas', 53),
#  ('basic', 53),
#  ('cameras', 53),
#  ('directly', 53),
#  ('enable', 53),
#  ('hence', 53),
#  ('issue', 53),
#  ('layer', 53),
#  ('position', 53),
#  ('prove', 53),
#  ('rapid', 53),
#  ('runtime', 53),
#  ('aims', 52),
#  ('controller', 52),
#  ('critical', 52),
#  ('fields', 52),
#  ('localization', 52),
#  ('sizes', 52),
#  ('specifically', 52),
#  ('usage', 52),
#  ('applying', 51),
#  ('benchmarks', 51),
#  ('circuits', 51),
#  ('compare', 51),
#  ('consists', 51),
#  ('content', 51),
#  ('correlation', 51),
#  ('corresponding', 51),
#  ('end', 51),
#  ('feasibility', 51),
#  ('measurements', 51),
#  ('nature', 51),
#  ('objective', 51),
#  ('points', 51),
#  ('processes', 51),
#  ('proof', 51),
#  ('queue', 51),
#  ('realworld', 51),
#  ('researchers', 51),
#  ('signal', 51),
#  ('survey', 51),
#  ('verified', 51),
#  ('benchmark', 50),
#  ('dynamics', 50),
#  ('effectively', 50),
#  ('elements', 50),
#  ('identified', 50),
#  ('measures', 50),
#  ('planning', 50),
#  ('postquantum', 50),
#  ('project', 50),
#  ('purpose', 50),
#  ('things', 50),
#  ('adaptive', 49),
#  ('aerial', 49),
#  ('allow', 49),
#  ('although', 49),
#  ('change', 49),
#  ('extracted', 49),
#  ('finite', 49),
#  ('impact', 49),
#  ('intelligence', 49),
#  ('long', 49),
#  ('lower', 49),
#  ('noise', 49),
#  ('reliability', 49),
#  ('resource', 49),
#  ('step', 49),
#  ('tests', 49),
#  ('trained', 49),
#  ('blockchain', 48),
#  ('continuous', 48),
#  ('determine', 48),
#  ('elliptic', 48),
#  ('encrypted', 48),
#  ('enhanced', 48),
#  ('extraction', 48),
#  ('imaging', 48),
#  ('include', 48),
#  ('last', 48),
#  ('optimizations', 48),
#  ('prototype', 48),
#  ('regions', 48),
#  ('systematic', 48),
#  ('total', 48),
#  ('aim', 47),
#  ('allowing', 47),
#  ('aspects', 47),
#  ('channel', 47),
#  ('exchange', 47),
#  ('extensive', 47),
#  ('gates', 47),
#  ('groups', 47),
#  ('improves', 47),
#  ('lack', 47),
#  ('nodes', 47),
#  ('occlusion', 47),
#  ('performing', 47),
#  ('retrieval', 47),
#  ('sequences', 47),
#  ('server', 47),
#  ('teaching', 47),
#  ('trajectory', 47),
#  ('abstract', 46),
#  ('cannot', 46),
#  ('computers', 46),
#  ('considering', 46),
#  ('disease', 46),
#  ('generating', 46),
#  ('materials', 46),
#  ('multiplication', 46),
#  ('needed', 46),
#  ('path', 46),
#  ('principles', 46),
#  ('production', 46),
#  ('static', 46),
#  ('variables', 46),
#  ('vector', 46),
#  ('amount', 45),
#  ('automation', 45),
#  ('capable', 45),
#  ('classical', 45),
#  ('description', 45),
#  ('enhance', 45),
#  ('faster', 45),
#  ('handle', 45),
#  ('infrastructure', 45),
#  ('interest', 45),
#  ('limitations', 45),
#  ('numerical', 45),
#  ('prior', 45),
#  ('sets', 45),
#  ('signature', 45),
#  ('subject', 45),
#  ('successfully', 45),
#  ('synthesis', 45),
#  ('us', 45),
#  ('wide', 45),
#  ('around', 44),
#  ('array', 44),
#  ('attributes', 44),
#  ('basis', 44),
#  ('build', 44),
#  ('contact', 44),
#  ('correctness', 44),
#  ('decision', 44),
#  ('employed', 44),
#  ('extract', 44),
#  ('maximum', 44),
#  ('mechanisms', 44),
#  ('mining', 44),
#  ('output', 44),
#  ('overcome', 44),
#  ('platforms', 44),
#  ('technical', 44),
#  ('track', 44),
#  ('walking', 44),
#  ('apply', 43),
#  ('crack', 43),
#  ('demonstrates', 43),
#  ('environmental', 43),
#  ('following', 43),
#  ('progress', 43),
#  ('region', 43),
#  ('relevant', 43),
#  ('service', 43),
#  ('steps', 43),
#  ('stored', 43),
#  ('validated', 43),
#  ('variety', 43),
#  ('active', 42),
#  ('activities', 42),
#  ('analyze', 42),
#  ('block', 42),
#  ('carried', 42),
#  ('constraint', 42),
#  ('either', 42),
#  ('examples', 42),
#  ('findings', 42),
#  ('full', 42),
#  ('great', 42),
#  ('highlevel', 42),
#  ('indicate', 42),
#  ('industry', 42),
#  ('learn', 42),
#  ('means', 42),
#  ('normal', 42),
#  ('optimizing', 42),
#  ('place', 42),
#  ('precise', 42),
#  ('private', 42),
#  ('science', 42),
#  ('sensitive', 42),
#  ('theoretical', 42),
#  ('urban', 42),
#  ('validate', 42),
#  ('virtual', 42),
#  ('analyses', 41),
#  ('contribution', 41),
#  ('course', 41),
#  ('cv', 41),
#  ('designs', 41),
#  ('index', 41),
#  ('instruction', 41),
#  ('introduces', 41),
#  ('investigate', 41),
#  ('parameter', 41),
#  ('popular', 41),
#  ('powerful', 41),
#  ('sequence', 41),
#  ('simulated', 41),
#  ('surveillance', 41),
#  ('variable', 41),
#  ('advanced', 40),
#  ('advances', 40),
#  ('alternative', 40),
#  ('binary', 40),
#  ('certain', 40),
#  ('combined', 40),
#  ('complete', 40),
#  ('computations', 40),
#  ('concerns', 40),
#  ('controlled', 40),
#  ('detailed', 40),
#  ('developing', 40),
#  ('ensure', 40),
#  ('geometric', 40),
#  ('includes', 40),
#  ('instructions', 40),
#  ('largescale', 40),
#  ('matrix', 40),
#  ('mechanical', 40),
#  ('message', 40),
#  ('parallelism', 40),
#  ('reference', 40),
#  ('temporal', 40),
#  ('underlying', 40),
#  ('version', 40),
#  ('would', 40),
#  ('adopted', 39),
#  ('collected', 39),
#  ('combining', 39),
#  ('condition', 39),
#  ('describes', 39),
#  ('displacement', 39),
#  ('easily', 39),
#  ('extended', 39),
#  ('face', 39),
#  ('factor', 39),
#  ('growing', 39),
#  ('operating', 39),
#  ('pattern', 39),
#  ('per', 39),
#  ('states', 39),
#  ('together', 39),
#  ('understand', 39),
#  ('underwater', 39),
#  ('verify', 39),
#  ('yet', 39),
#  ('accurately', 38),
#  ('arm', 38),
#  ('background', 38),
#  ('collection', 38),
#  ('correct', 38),
#  ('effort', 38),
#  ('etc', 38),
#  ('every', 38),
#  ('facilitate', 38),
#  ('initial', 38),
#  ('latticebased', 38),
#  ('length', 38),
#  ('mm', 38),
#  ('modern', 38),
#  ('procedure', 38),
#  ('sequential', 38),
#  ('statistical', 38),
#  ('success', 38),
#  ('usually', 38),
#  ('whether', 38),
#  ('another', 37),
#  ('cipher', 37),
#  ('classify', 37),
#  ('consider', 37),
#  ('core', 37),
#  ('creating', 37),
#  ('currently', 37),
#  ('evolutionary', 37),
#  ('files', 37),
#  ('frequency', 37),
#  ('growth', 37),
#  ('java', 37),
#  ('light', 37),
#  ('manipulation', 37),
#  ('nosql', 37),
#  ('run', 37),
#  ('running', 37),
#  ('sampling', 37),
#  ('simulations', 37),
#  ('solving', 37),
#  ('unmanned', 37),
#  ('utilized', 37),
#  ('activity', 36),
#  ('baseline', 36),
#  ('built', 36),
#  ('capability', 36),
#  ('classes', 36),
#  ('constructed', 36),
#  ('controllers', 36),
#  ('cryptosystem', 36),
#  ('described', 36),
#  ('done', 36),
#  ('electronic', 36),
#  ('expected', 36),
#  ('external', 36),
#  ('fundamental', 36),
#  ('generates', 36),
#  ('learningbased', 36),
#  ('manipulator', 36),
#  ('ones', 36),
#  ('optimize', 36),
#  ('outperforms', 36),
#  ('partitioning', 36),
#  ('pedestrian', 36),
#  ('previously', 36),
#  ('regarding', 36),
#  ('respect', 36),
#  ('risk', 36),
#  ('structured', 36),
#  ('syntax', 36),
#  ('take', 36),
#  ('third', 36),
#  ('whole', 36),
#  ('always', 35),
#  ('assembly', 35),
#  ('children', 35),
#  ('clustering', 35),
#  ('comparing', 35),
#  ('detecting', 35),
#  ('factors', 35),
#  ('false', 35),
#  ('focused', 35),
#  ('ground', 35),
#  ('hard', 35),
#  ('idea', 35),
#  ('imagery', 35),
#  ('implementing', 35),
#  ('internal', 35),
#  ('manner', 35),
#  ('material', 35),
#  ('outcomes', 35),
#  ('pipeline', 35),
#  ('plant', 35),
#  ('predict', 35),
#  ('product', 35),
#  ('proved', 35),
#  ('relationship', 35),
#  ('relative', 35),
#  ('utility', 35),
#  ('weight', 35),
#  ('wireless', 35),
#  ('agreement', 34),
#  ('ai', 34),
#  ('capacity', 34),
#  ('codes', 34),
#  ('connected', 34),
#  ('desired', 34),
#  ('discussed', 34),
#  ('early', 34),
#  ('events', 34),
#  ('gate', 34),
#  ('generic', 34),
#  ('give', 34),
#  ('gpu', 34),
#  ('importance', 34),
#  ('independent', 34),
#  ('investigated', 34),
#  ('life', 34),
#  ('machines', 34),
#  ('manufacturing', 34),
#  ('parts', 34),
#  ('past', 34),
#  ('performs', 34),
#  ('positive', 34),
#  ('scalable', 34),
#  ('sources', 34),
#  ('stages', 34),
#  ('standards', 34),
#  ('transmission', 34),
#  ('annotation', 33),
#  ('avoid', 33),
#  ('compression', 33),
#  ('concepts', 33),
#  ('conclusions', 33),
#  ('define', 33),
#  ('defined', 33),
#  ('despite', 33),
#  ('diverse', 33),
#  ('domains', 33),
#  ('emerging', 33),
#  ('exploit', 33),
#  ('extension', 33),
#  ('focuses', 33),
#  ('intervention', 33),
#  ('joint', 33),
#  ('motor', 33),
#  ('particularly', 33),
#  ('perception', 33),
#  ('primary', 33),
#  ('produce', 33),
#  ('quantitative', 33),
#  ('rdb', 33),
#  ('represent', 33),
#  ('sample', 33),
#  ('series', 33),
#  ('shared', 33),
#  ('stereo', 33),
#  ('strong', 33),
#  ('studied', 33),
#  ('translation', 33),
#  ('unique', 33),
#  ('benefits', 32),
#  ('bridge', 32),
#  ('capture', 32),
#  ('configuration', 32),
#  ('contrast', 32),
#  ('criteria', 32),
#  ('crucial', 32),
#  ('degree', 32),
#  ('deployment', 32),
#  ('detected', 32),
#  ('driving', 32),
#  ('enabling', 32),
#  ('established', 32),
#  ...]

# %%
# Stem
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()

def stem_text(text):
    ps = SnowballStemmer('english')
    return " ".join([ps.stem(w) for w in w_tokenizer.tokenize(text)])

df['preprocessed'] = df['noStopwords'].apply(stem_text)

# %%
a = countAndSort(df['preprocessed'])
a
# Out:
# [('use', 2024),
#  ('data', 1385),
#  ('system', 1368),
#  ('propos', 1238),
#  ('model', 1061),
#  ('method', 983),
#  ('comput', 979),
#  ('perform', 891),
#  ('base', 826),
#  ('imag', 805),
#  ('algorithm', 798),
#  ('robot', 789),
#  ('result', 771),
#  ('secur', 737),
#  ('paper', 711),
#  ('approach', 699),
#  ('databas', 687),
#  ('applic', 673),
#  ('design', 641),
#  ('develop', 597),
#  ('compil', 589),
#  ('present', 582),
#  ('inform', 560),
#  ('process', 558),
#  ('detect', 555),
#  ('learn', 553),
#  ('implement', 547),
#  ('network', 540),
#  ('differ', 523),
#  ('provid', 520),
#  ('relat', 517),
#  ('show', 514),
#  ('improv', 505),
#  ('time', 498),
#  ('techniqu', 484),
#  ('control', 480),
#  ('optim', 472),
#  ('studi', 461),
#  ('program', 460),
#  ('also', 435),
#  ('effici', 433),
#  ('work', 427),
#  ('evalu', 424),
#  ('generat', 423),
#  ('analysi', 420),
#  ('problem', 411),
#  ('scheme', 410),
#  ('research', 395),
#  ('new', 391),
#  ('requir', 385),
#  ('object', 382),
#  ('compar', 378),
#  ('featur', 378),
#  ('key', 374),
#  ('two', 372),
#  ('effect', 364),
#  ('oper', 347),
#  ('structur', 347),
#  ('howev', 341),
#  ('task', 341),
#  ('test', 340),
#  ('code', 335),
#  ('technolog', 334),
#  ('framework', 330),
#  ('quantum', 330),
#  ('one', 329),
#  ('vision', 329),
#  ('achiev', 318),
#  ('languag', 318),
#  ('encrypt', 315),
#  ('set', 315),
#  ('measur', 313),
#  ('high', 306),
#  ('increas', 300),
#  ('exist', 293),
#  ('function', 292),
#  ('architectur', 290),
#  ('dataset', 289),
#  ('queri', 288),
#  ('train', 288),
#  ('complex', 287),
#  ('user', 284),
#  ('integr', 283),
#  ('challeng', 280),
#  ('experi', 278),
#  ('map', 278),
#  ('accuraci', 276),
#  ('demonstr', 275),
#  ('visual', 274),
#  ('environ', 273),
#  ('reduc', 273),
#  ('number', 265),
#  ('construct', 259),
#  ('estim', 258),
#  ('dynam', 253),
#  ('first', 252),
#  ('attack', 251),
#  ('multipl', 248),
#  ('protocol', 247),
#  ('deep', 246),
#  ('tool', 245),
#  ('includ', 244),
#  ('type', 238),
#  ('import', 236),
#  ('graph', 235),
#  ('appli', 231),
#  ('cryptographi', 230),
#  ('transform', 229),
#  ('novel', 226),
#  ('track', 225),
#  ('allow', 224),
#  ('need', 221),
#  ('solut', 221),
#  ('field', 216),
#  ('obtain', 216),
#  ('simul', 215),
#  ('execut', 213),
#  ('experiment', 211),
#  ('support', 211),
#  ('communic', 210),
#  ('mani', 210),
#  ('devic', 208),
#  ('larg', 208),
#  ('make', 208),
#  ('manag', 208),
#  ('addit', 207),
#  ('introduc', 207),
#  ('machin', 206),
#  ('signific', 206),
#  ('neural', 205),
#  ('memori', 203),
#  ('video', 202),
#  ('sever', 201),
#  ('various', 201),
#  ('specif', 200),
#  ('standard', 200),
#  ('power', 198),
#  ('combin', 195),
#  ('order', 195),
#  ('case', 194),
#  ('recent', 194),
#  ('cloud', 191),
#  ('human', 191),
#  ('size', 191),
#  ('softwar', 189),
#  ('automat', 187),
#  ('semant', 187),
#  ('sensor', 186),
#  ('area', 184),
#  ('mechan', 184),
#  ('valid', 184),
#  ('level', 183),
#  ('parallel', 183),
#  ('due', 182),
#  ('error', 182),
#  ('target', 182),
#  ('limit', 181),
#  ('current', 180),
#  ('autom', 179),
#  ('well', 176),
#  ('hardwar', 175),
#  ('util', 175),
#  ('predict', 174),
#  ('consid', 173),
#  ('without', 170),
#  ('extract', 169),
#  ('strategi', 169),
#  ('local', 168),
#  ('better', 167),
#  ('three', 167),
#  ('distribut', 166),
#  ('paramet', 166),
#  ('general', 165),
#  ('identifi', 163),
#  ('may', 163),
#  ('practic', 163),
#  ('access', 161),
#  ('point', 161),
#  ('adapt', 160),
#  ('cost', 158),
#  ('direct', 158),
#  ('enabl', 157),
#  ('state', 157),
#  ('segment', 156),
#  ('speed', 156),
#  ('analyz', 154),
#  ('final', 153),
#  ('robust', 153),
#  ('theori', 153),
#  ('camera', 151),
#  ('select', 151),
#  ('interact', 150),
#  ('vehicl', 150),
#  ('valu', 149),
#  ('assess', 147),
#  ('authent', 147),
#  ('domain', 145),
#  ('focus', 145),
#  ('iot', 145),
#  ('recognit', 145),
#  ('term', 145),
#  ('possibl', 144),
#  ('capabl', 143),
#  ('input', 143),
#  ('potenti', 143),
#  ('sourc', 142),
#  ('way', 142),
#  ('address', 141),
#  ('tradit', 141),
#  ('condit', 140),
#  ('monitor', 140),
#  ('avail', 139),
#  ('knowledg', 139),
#  ('main', 139),
#  ('qualiti', 139),
#  ('storag', 139),
#  ('classif', 138),
#  ('describ', 137),
#  ('activ', 136),
#  ('futur', 136),
#  ('posit', 136),
#  ('articl', 135),
#  ('group', 135),
#  ('build', 134),
#  ('chang', 134),
#  ('platform', 133),
#  ('find', 132),
#  ('creat', 131),
#  ('discuss', 131),
#  ('space', 131),
#  ('behavior', 130),
#  ('aim', 129),
#  ('depend', 129),
#  ('enhanc', 129),
#  ('motion', 129),
#  ('issu', 128),
#  ('solv', 128),
#  ('regist', 127),
#  ('sampl', 127),
#  ('correct', 126),
#  ('verifi', 126),
#  ('investig', 125),
#  ('previous', 124),
#  ('modul', 123),
#  ('product', 123),
#  ('collect', 122),
#  ('consist', 122),
#  ('processor', 122),
#  ('random', 122),
#  ('rate', 122),
#  ('cryptograph', 121),
#  ('energi', 121),
#  ('mean', 121),
#  ('part', 121),
#  ('respect', 121),
#  ('constraint', 120),
#  ('natur', 120),
#  ('review', 120),
#  ('share', 120),
#  ('store', 120),
#  ('therefor', 119),
#  ('accur', 118),
#  ('explor', 118),
#  ('manipul', 118),
#  ('averag', 117),
#  ('becom', 117),
#  ('conduct', 117),
#  ('flow', 117),
#  ('industri', 117),
#  ('precis', 117),
#  ('success', 117),
#  ('benchmark', 116),
#  ('patient', 116),
#  ('resourc', 116),
#  ('convolut', 115),
#  ('soft', 115),
#  ('stateoftheart', 115),
#  ('within', 115),
#  ('advanc', 114),
#  ('embed', 114),
#  ('indic', 114),
#  ('realtim', 114),
#  ('represent', 113),
#  ('autonom', 112),
#  ('thus', 112),
#  ('forc', 111),
#  ('phase', 111),
#  ('call', 110),
#  ('help', 110),
#  ('intellig', 110),
#  ('search', 110),
#  ('servic', 110),
#  ('small', 110),
#  ('loop', 109),
#  ('mobil', 109),
#  ('singl', 109),
#  ('determin', 108),
#  ('public', 108),
#  ('similar', 108),
#  ('extens', 107),
#  ('repres', 107),
#  ('student', 107),
#  ('circuit', 106),
#  ('filter', 106),
#  ('privaci', 106),
#  ('prove', 106),
#  ('region', 106),
#  ('color', 105),
#  ('could', 105),
#  ('contribut', 104),
#  ('low', 104),
#  ('comparison', 103),
#  ('variabl', 103),
#  ('wide', 103),
#  ('abl', 102),
#  ('digit', 102),
#  ('exampl', 102),
#  ('rang', 102),
#  ('associ', 101),
#  ('form', 101),
#  ('match', 101),
#  ('given', 100),
#  ('properti', 100),
#  ('like', 99),
#  ('particular', 99),
#  ('shape', 99),
#  ('class', 98),
#  ('ontolog', 98),
#  ('protect', 98),
#  ('second', 98),
#  ('understand', 98),
#  ('common', 97),
#  ('engin', 97),
#  ('formal', 97),
#  ('health', 97),
#  ('pattern', 97),
#  ('real', 97),
#  ('best', 96),
#  ('characterist', 96),
#  ('even', 96),
#  ('linear', 96),
#  ('moreov', 96),
#  ('particip', 96),
#  ('sinc', 96),
#  ('toward', 96),
#  ('transfer', 96),
#  ('assist', 95),
#  ('continu', 95),
#  ('employ', 95),
#  ('file', 95),
#  ('observ', 95),
#  ('scenario', 95),
#  ('surfac', 95),
#  ('abil', 94),
#  ('hybrid', 93),
#  ('individu', 93),
#  ('manual', 93),
#  ('often', 93),
#  ('physic', 93),
#  ('sens', 93),
#  ('compon', 92),
#  ('convent', 92),
#  ('extend', 92),
#  ('identif', 92),
#  ('simpl', 92),
#  ('sql', 92),
#  ('step', 92),
#  ('classifi', 91),
#  ('metric', 91),
#  ('refer', 91),
#  ('scale', 91),
#  ('secret', 90),
#  ('exploit', 89),
#  ('major', 89),
#  ('minim', 89),
#  ('produc', 89),
#  ('sequenc', 89),
#  ('year', 89),
#  ('advantag', 88),
#  ('concept', 88),
#  ('context', 88),
#  ('furthermor', 88),
#  ('logic', 88),
#  ('take', 88),
#  ('layer', 87),
#  ('schedul', 87),
#  ('smart', 87),
#  ('gate', 86),
#  ('materi', 86),
#  ('safeti', 86),
#  ('spatial', 86),
#  ('suitabl', 86),
#  ('reliabl', 85),
#  ('rule', 85),
#  ('attent', 84),
#  ('complet', 84),
#  ('defin', 84),
#  ('detail', 84),
#  ('express', 84),
#  ('fast', 84),
#  ('ie', 84),
#  ('interfac', 84),
#  ('project', 84),
#  ('abstract', 83),
#  ('adopt', 83),
#  ('flexibl', 83),
#  ('gait', 83),
#  ('instruct', 83),
#  ('involv', 83),
#  ('numer', 83),
#  ('suggest', 83),
#  ('cluster', 82),
#  ('goal', 82),
#  ('hand', 82),
#  ('handl', 82),
#  ('higher', 82),
#  ('literatur', 82),
#  ('promis', 82),
#  ('remot', 82),
#  ('run', 82),
#  ('via', 82),
#  ('onlin', 81),
#  ('proof', 81),
#  ('ensur', 80),
#  ('follow', 80),
#  ('inspect', 80),
#  ('methodolog', 80),
#  ('normal', 80),
#  ('subject', 80),
#  ('artifici', 79),
#  ('copyright', 79),
#  ('correspond', 79),
#  ('fulli', 79),
#  ('lead', 79),
#  ('actuat', 78),
#  ('alloc', 78),
#  ('clinic', 78),
#  ('eg', 78),
#  ('factor', 78),
#  ('annot', 77),
#  ('bit', 77),
#  ('block', 77),
#  ('lightweight', 77),
#  ('must', 77),
#  ('overhead', 77),
#  ('rapid', 77),
#  ('role', 77),
#  ('signal', 77),
#  ('chaotic', 76),
#  ('deploy', 76),
#  ('good', 76),
#  ('navig', 76),
#  ('respons', 76),
#  ('trajectori', 76),
#  ('translat', 76),
#  ('connect', 75),
#  ('curv', 75),
#  ('emerg', 75),
#  ('still', 75),
#  ('internet', 74),
#  ('less', 74),
#  ('name', 74),
#  ('open', 74),
#  ('retriev', 74),
#  ('accord', 73),
#  ('captur', 73),
#  ('caus', 73),
#  ('distanc', 73),
#  ('reduct', 73),
#  ('schema', 73),
#  ('comprehens', 72),
#  ('correl', 72),
#  ('essenti', 72),
#  ('feasibl', 72),
#  ('feedback', 72),
#  ('interest', 72),
#  ('locat', 72),
#  ('nonlinear', 71),
#  ('offer', 71),
#  ('procedur', 71),
#  ('report', 71),
#  ('bodi', 70),
#  ('contain', 70),
#  ('face', 70),
#  ('heterogen', 70),
#  ('initi', 70),
#  ('organ', 70),
#  ('plan', 70),
#  ('reason', 70),
#  ('server', 70),
#  ('shown', 70),
#  ('statist', 70),
#  ('view', 70),
#  ('attribut', 69),
#  ('concern', 69),
#  ('consumpt', 69),
#  ('establish', 69),
#  ('found', 69),
#  ('path', 69),
#  ('preserv', 69),
#  ('reli', 69),
#  ('among', 68),
#  ('analys', 68),
#  ('bound', 68),
#  ('channel', 68),
#  ('check', 68),
#  ('diseas', 68),
#  ('element', 68),
#  ('give', 68),
#  ('outperform', 68),
#  ('pose', 68),
#  ('score', 68),
#  ('world', 68),
#  ('facilit', 67),
#  ('four', 67),
#  ('maintain', 67),
#  ('prototyp', 67),
#  ('purpos', 67),
#  ('record', 67),
#  ('traffic', 67),
#  ('web', 67),
#  ('edg', 66),
#  ('especi', 66),
#  ('content', 65),
#  ('descript', 65),
#  ('effort', 65),
#  ('encod', 65),
#  ('made', 65),
#  ('node', 65),
#  ('origin', 65),
#  ('peopl', 65),
#  ('place', 65),
#  ('scalabl', 65),
#  ('vector', 65),
#  ('acceler', 64),
#  ('crack', 64),
#  ('stroke', 64),
#  ('amount', 63),
#  ('carri', 63),
#  ('cours', 63),
#  ('deriv', 63),
#  ('event', 63),
#  ('fuzzi', 63),
#  ('lack', 63),
#  ('loss', 63),
#  ('optic', 63),
#  ('sensit', 63),
#  ('social', 63),
#  ('weight', 63),
#  ('benefit', 62),
#  ('cycl', 62),
#  ('much', 62),
#  ('principl', 62),
#  ('progress', 62),
#  ('reach', 62),
#  ('survey', 62),
#  ('verif', 62),
#  ('across', 61),
#  ('array', 61),
#  ('configur', 61),
#  ('consider', 61),
#  ('difficult', 61),
#  ('divers', 61),
#  ('fusion', 61),
#  ('surgic', 61),
#  ('walk', 61),
#  ('ad', 60),
#  ('along', 60),
#  ('evolv', 60),
#  ('known', 60),
#  ('messag', 60),
#  ('necessari', 60),
#  ('output', 60),
#  ('programm', 60),
#  ('signatur', 60),
#  ('stage', 60),
#  ('aspect', 59),
#  ('big', 59),
#  ('decis', 59),
#  ('depth', 59),
#  ('healthcar', 59),
#  ('infrastructur', 59),
#  ('last', 59),
#  ('overal', 59),
#  ('tree', 59),
#  ('degre', 58),
#  ('global', 58),
#  ('guarante', 58),
#  ('letter', 58),
#  ('medic', 58),
#  ('partit', 58),
#  ('person', 58),
#  ('plant', 58),
#  ('theoret', 58),
#  ('visionbas', 58),
#  ('affect', 57),
#  ('classic', 57),
#  ('popular', 57),
#  ('recommend', 57),
#  ('remain', 57),
#  ('systemat', 57),
#  ('blockchain', 56),
#  ('fabric', 56),
#  ('format', 56),
#  ('nois', 56),
#  ('outcom', 56),
#  ('receiv', 56),
#  ('teach', 56),
#  ('updat', 56),
#  ('avoid', 55),
#  ('basic', 55),
#  ('demand', 55),
#  ('desir', 55),
#  ('fpga', 55),
#  ('gain', 55),
#  ('impact', 55),
#  ('index', 55),
#  ('instanc', 55),
#  ('intern', 55),
#  ('move', 55),
#  ('pipelin', 55),
#  ('resist', 55),
#  ('tabl', 55),
#  ('cnn', 54),
#  ('collabor', 54),
#  ('critic', 54),
#  ('great', 54),
#  ('incorpor', 54),
#  ('recogn', 54),
#  ('runtim', 54),
#  ('thing', 54),
#  ('total', 54),
#  ('unit', 54),
#  ('vulner', 54),
#  ('henc', 53),
#  ('intervent', 53),
#  ('mask', 53),
#  ('occlus', 53),
#  ('optimis', 53),
#  ('altern', 52),
#  ('calcul', 52),
#  ('cipher', 52),
#  ('competit', 52),
#  ('conclus', 52),
#  ('cryptosystem', 52),
#  ('drive', 52),
#  ('ellipt', 52),
#  ('end', 52),
#  ('independ', 52),
#  ('interpret', 52),
#  ('joint', 52),
#  ('lower', 52),
#  ('mine', 52),
#  ('movement', 52),
#  ('question', 52),
#  ('queue', 52),
#  ('regard', 52),
#  ('relationship', 52),
#  ('usag', 52),
#  ('approxim', 51),
#  ('exchang', 51),
#  ('hard', 51),
#  ('label', 51),
#  ('realworld', 51),
#  ('trace', 51),
#  ('varieti', 51),
#  ('bridg', 50),
#  ('displac', 50),
#  ('fit', 50),
#  ('overcom', 50),
#  ('postquantum', 50),
#  ('action', 49),
#  ('aerial', 49),
#  ('although', 49),
#  ('finit', 49),
#  ('frame', 49),
#  ('load', 49),
#  ('long', 49),
#  ('mode', 49),
#  ('prevent', 49),
#  ('adversari', 48),
#  ('appear', 48),
#  ('author', 48),
#  ('consum', 48),
#  ('custom', 48),
#  ('equival', 48),
#  ('librari', 48),
#  ('relev', 48),
#  ('risk', 48),
#  ('specifi', 48),
#  ('technic', 48),
#  ('univers', 48),
#  ('volum', 48),
#  ('accept', 47),
#  ('behaviour', 47),
#  ('day', 47),
#  ('expert', 47),
#  ('grasp', 47),
#  ('grow', 47),
#  ('prior', 47),
#  ('scienc', 47),
#  ('uav', 47),
#  ('usual', 47),
#  ('virtual', 47),
#  ('arm', 46),
#  ('cannot', 46),
#  ('contact', 46),
#  ('deal', 46),
#  ('document', 46),
#  ('electron', 46),
#  ('geometr', 46),
#  ('idea', 46),
#  ('light', 46),
#  ('pair', 46),
#  ('pedestrian', 46),
#  ('reveal', 46),
#  ('static', 46),
#  ('watermark', 46),
#  ('basi', 45),
#  ('binari', 45),
#  ('children', 45),
#  ('faster', 45),
#  ('modifi', 45),
#  ('synthesi', 45),
#  ('us', 45),
#  ('version', 45),
#  ('around', 44),
#  ('character', 44),
#  ('compress', 44),
#  ('elimin', 44),
#  ('examin', 44),
#  ('expect', 44),
#  ('formul', 44),
#  ('maximum', 44),
#  ('assembl', 43),
#  ('candid', 43),
#  ('close', 43),
#  ('core', 43),
#  ('decad', 43),
#  ('environment', 43),
#  ('fundament', 43),
#  ('infer', 43),
#  ('length', 43),
#  ('link', 43),
#  ('play', 43),
#  ('privat', 43),
#  ('reconstruct', 43),
#  ('scene', 43),
#  ('stream', 43),
#  ('synchron', 43),
#  ('tempor', 43),
#  ('concurr', 42),
#  ('either', 42),
#  ('full', 42),
#  ('highlevel', 42),
#  ('instrument', 42),
#  ('manufactur', 42),
#  ('rotat', 42),
#  ('urban', 42),
#  ('acquir', 41),
#  ('analyt', 41),
#  ('background', 41),
#  ('count', 41),
#  ('cv', 41),
#  ('difficulti', 41),
#  ('frequenc', 41),
#  ('live', 41),
#  ('modern', 41),
#  ('quantit', 41),
#  ('strong', 41),
#  ('surveil', 41),
#  ('trend', 41),
#  ('yield', 41),
#  ('aggreg', 40),
#  ('baselin', 40),
#  ('certain', 40),
#  ('citi', 40),
#  ('educ', 40),
#  ('get', 40),
#  ('intens', 40),
#  ('largescal', 40),
#  ('matrix', 40),
#  ('qubit', 40),
#  ('realiz', 40),
#  ('save', 40),
#  ('sequenti', 40),
#  ('skill', 40),
#  ('special', 40),
#  ('under', 40),
#  ('would', 40),
#  ('write', 40),
#  ('capac', 39),
#  ('decrypt', 39),
#  ('defect', 39),
#  ('easili', 39),
#  ('extern', 39),
#  ('magnet', 39),
#  ('opportun', 39),
#  ('per', 39),
#  ('pixel', 39),
#  ('polynomi', 39),
#  ('scan', 39),
#  ('simultan', 39),
#  ('third', 39),
#  ('togeth', 39),
#  ('typic', 39),
#  ('underwat', 39),
#  ('variant', 39),
#  ('yet', 39),
#  ('convert', 38),
#  ('cover', 38),
#  ('done', 38),
#  ('etc', 38),
#  ('everi', 38),
#  ('latticebas', 38),
#  ('mathemat', 38),
#  ('mm', 38),
#  ('modal', 38),
#  ('percept', 38),
#  ('prefer', 38),
#  ('whether', 38),
#  ('ai', 37),
#  ('angl', 37),
#  ('anoth', 37),
#  ('augment', 37),
#  ('composit', 37),
#  ('disturb', 37),
#  ('evolutionari', 37),
#  ('fault', 37),
#  ('ground', 37),
#  ('growth', 37),
#  ('interv', 37),
#  ('java', 37),
#  ('leverag', 37),
#  ('nosql', 37),
#  ('prune', 37),
#  ('quantifi', 37),
#  ('regular', 37),
#  ('satisfi', 37),
#  ('situat', 37),
#  ('style', 37),
#  ('unman', 37),
#  ('workflow', 37),
#  ('assign', 36),
#  ('built', 36),
#  ('calibr', 36),
#  ('decomposit', 36),
#  ('fuse', 36),
#  ('iter', 36),
#  ('learningbas', 36),
#  ('modular', 36),
#  ('syntax', 36),
#  ('threshold', 36),
#  ('trial', 36),
#  ('whole', 36),
#  ('wireless', 36),
#  ('agent', 35),
#  ('agreement', 35),
#  ('alway', 35),
#  ('answer', 35),
#  ('balanc', 35),
#  ('cell', 35),
#  ('center', 35),
#  ('contrast', 35),
#  ('equip', 35),
#  ('explicit', 35),
#  ('fals', 35),
#  ('fix', 35),
#  ('imageri', 35),
#  ('influenc', 35),
#  ('manner', 35),
#  ('mitig', 35),
#  ('motiv', 35),
#  ('motor', 35),
#  ('orient', 35),
#  ('paradigm', 35),
#  ('threat', 35),
#  ('transmiss', 35),
#  ('uniqu', 35),
#  ('account', 34),
#  ('actual', 34),
#  ('al', 34),
#  ('align', 34),
#  ('coordin', 34),
#  ('countermeasur', 34),
#  ('earli', 34),
#  ('entiti', 34),
#  ('generic', 34),
#  ('gpu', 34),
#  ('grid', 34),
#  ('insight', 34),
#  ('life', 34),
#  ('partial', 34),
#  ('past', 34),
#  ('print', 34),
#  ('replac', 34),
#  ('restrict', 34),
#  ('round', 34),
#  ('transact', 34),
#  ('besid', 33),
#  ('communiti', 33),
#  ('crucial', 33),
#  ('despit', 33),
#  ('expens', 33),
#  ('keep', 33),
#  ('obstacl', 33),
#  ('polici', 33),
#  ('primari', 33),
#  ('rdb', 33),
#  ('reconfigur', 33),
#  ('seri', 33),
#  ('short', 33),
#  ('start', 33),
#  ('stereo', 33),
#  ('summar', 33),
#  ('anomali', 32),
#  ('assumpt', 32),
#  ('biolog', 32),
#  ('coupl', 32),
#  ('criteria', 32),
#  ('differenti', 32),
#  ('dimens', 32),
#  ('et', 32),
#  ('facial', 32),
#  ('free', 32),
#  ('gap', 32),
#  ('guid', 32),
#  ('highlight', 32),
#  ('ml', 32),
#  ('parti', 32),
#  ('rehabilit', 32),
#  ('resolut', 32),
#  ('safe', 32),
#  ('separ', 32),
#  ('substanti', 32),
#  ('superior', 32),
#  ('swarm', 32),
#  ('taken', 32),
#  ('therapi', 32),
#  ('uncertainti', 32),
#  ('upper', 32),
#  ('vari', 32),
#  ('appropri', 31),
#  ('attempt', 31),
#  ('constrain', 31),
#  ('crop', 31),
#  ('exponenti', 31),
#  ('migrat', 31),
#  ('multicor', 31),
#  ('multimod', 31),
#  ('opensourc', 31),
#  ('proven', 31),
#  ('remov', 31),
#  ('strength', 31),
#  ('text', 31),
#  ('unsupervis', 31),
#  ('water', 31),
#  ('wearabl', 31),
#  ('care', 30),
#  ('damag', 30),
#  ('easi', 30),
#  ('extrem', 30),
#  ('failur', 30),
#  ('game', 30),
#  ('hash', 30),
#  ('ideal', 30),
#  ('instead', 30),
#  ('sensori', 30),
#  ('side', 30),
#  ('sidechannel', 30),
#  ('stabil', 30),
#  ('teacher', 30),
#  ('weak', 30),
#  ('aid', 29),
#  ('art', 29),
#  ('card', 29),
#  ('choic', 29),
#  ('conflict', 29),
#  ('convers', 29),
#  ('cut', 29),
#  ('diagnosi', 29),
#  ('electr', 29),
#  ('frequent', 29),
#  ('fruit', 29),
#  ('heurist', 29),
#  ('home', 29),
#  ('illustr', 29),
#  ('integ', 29),
#  ('kind', 29),
#  ('least', 29),
#  ('morpholog', 29),
#  ('multipli', 29),
#  ('popul', 29),
#  ('quick', 29),
#  ('rdbms', 29),
#  ('sustain', 29),
#  ('templat', 29),
#  ('unknown', 29),
#  ('appl', 28),
#  ('attract', 28),
#  ...]

# %%
# tf-idf
v = TfidfVectorizer(max_df=0.25, min_df=1, ngram_range=(1,2), stop_words=['data','use', 'propos'])
x = v.fit_transform(df['preprocessed'])

# %%
v.stop_words_
# Out:
# {'polynomialtim interv',
#  'develop empir',
#  'semwebnet userfriend',
#  'floor human',
#  'respons extern',
#  'account weight',
#  'process feasibl',
#  'organ databas',
#  'search ns',
#  'inform processor',
#  'featur raw',
#  'evidenc number',
#  'also morpholog',
#  'process simplifi',
#  'weight recurr',
#  'client end',
#  'convent displac',
#  'prefer store',
#  'process way',
#  'cryptograph role',
#  'one qubit',
#  'flight number',
#  'subsampl pixel',
#  'kelvin voigtgener',
#  'newgener relat',
#  'spoof prevent',
#  'elbow',
#  'select flexibl',
#  'secret lwe',
#  'therebi construct',
#  'compil static',
#  'cyber health',
#  'vesselspe',
#  'featur extractionth',
#  'imag msi',
#  'support user',
#  'import artifici',
#  'reconfigur shapemorph',
#  'upper lower',
#  'monitor scenario',
#  'assist advanc',
#  'moreov metric',
#  'collabor compil',
#  'specif detect',
#  'current major',
#  'tls method',
#  'support opportun',
#  'understand reviewsinc',
#  'almost half',
#  'forget problem',
#  'yield poor',
#  'sensor fulfil',
#  'modul ntt',
#  'captur environment',
#  'level trial',
#  'optim rehabilit',
#  'show close',
#  'attack denialofservic',
#  'anomalyfre',
#  'softwar layer',
#  'fuse fbg',
#  'preferencesbas optim',
#  'pseudo label',
#  'blade lcoe',
#  'fruit grade',
#  'multiton',
#  'metaeth',
#  'decrypt display',
#  'provid tabular',
#  'rout meet',
#  'demand popular',
#  'dens highresolut',
#  'resourc great',
#  'research outcom',
#  'hydraul pressesa',
#  'develop mpiawar',
#  'geodes curv',
#  'way defin',
#  'avail benchmark',
#  'spirit individu',
#  'unseen class',
#  'impact processor',
#  'fragment general',
#  'trapdoor func',
#  'computingheterogen comput',
#  'framework minim',
#  'accommod intellig',
#  'formatscomplex scenescamera',
#  'peopl want',
#  'optim unoptim',
#  'faith',
#  'respect privat',
#  'dme effici',
#  'angular differ',
#  'ring exact',
#  'cts',
#  'rat',
#  'goal extens',
#  'brush teeth',
#  'hysteresi demonstr',
#  'recommend wc',
#  'millimeterwav radar',
#  'changevisu place',
#  'clinic approach',
#  'physic train',
#  'parti must',
#  'tonguerobot map',
#  'cv revolution',
#  'discuss applic',
#  'margin practic',
#  'composit structur',
#  'qualit questionnair',
#  'mobileweb',
#  'optic inform',
#  'moreov statist',
#  'implement gfm',
#  'imagesexist',
#  'imag appli',
#  'signal never',
#  'fact fell',
#  'term consid',
#  'attack encrypt',
#  'perturb digit',
#  'real implement',
#  'punch anticip',
#  'togeth newborn',
#  'ct analysi',
#  'messagechosen',
#  'wearabl person',
#  'allround way',
#  'hierarchi perform',
#  'futur perspect',
#  'address inabl',
#  'area imag',
#  'assumpt yet',
#  'matur industri',
#  'evalu sensor',
#  'fusion power',
#  'cluster format',
#  'input consist',
#  'dmodel nuclear',
#  'oneself wear',
#  'auc sensit',
#  'moreov perform',
#  'transpos array',
#  'manag appli',
#  'cyclic henc',
#  'multipl copi',
#  'enabl soc',
#  'exampl lightweight',
#  'mean detect',
#  'aspect implementationsnowaday',
#  'collabor invest',
#  'bitplan instead',
#  'famous ring',
#  'local resourc',
#  'common framework',
#  'annot specif',
#  'therefor second',
#  'creat need',
#  'guarante therefor',
#  'exclud analysi',
#  'converg achiev',
#  'mysql sql',
#  'import fli',
#  'demand econom',
#  'entiti might',
#  'domain extens',
#  'knee comput',
#  'endow optic',
#  'stiff achiev',
#  'perform formul',
#  'demonstr observ',
#  'show rsquar',
#  'app monitor',
#  'prevent inspect',
#  'develop logic',
#  'exvc gas',
#  'environ alloc',
#  'theoret find',
#  'readevalprint loop',
#  'inherit bodi',
#  'reason hazard',
#  'lidartag',
#  'invert binari',
#  'map mpmct',
#  'small constantfactor',
#  'control simpler',
#  'machin wide',
#  'softwar hardwarefir',
#  'remov extra',
#  'highthroughput assess',
#  'request inform',
#  'section possibl',
#  'fractal',
#  'remot perform',
#  'bkz',
#  'constantfactor overhead',
#  'minim sensori',
#  'faulti symmetri',
#  'excavatortruck',
#  'teacher therefor',
#  'variabl method',
#  'layer inbetween',
#  'visual part',
#  'versus geometr',
#  'devic convolut',
#  'well circuit',
#  'foundat reason',
#  'foundat grid',
#  'rnn activ',
#  'advanc nonadjust',
#  'distribut involv',
#  'semant also',
#  'sensor integr',
#  'util classif',
#  'brigg',
#  'asynchron design',
#  'rdbmsbase',
#  'angl improv',
#  'relat base',
#  'catastroph loss',
#  'desir compress',
#  'develop lerner',
#  'simtor',
#  'tool video',
#  'analyz multidimension',
#  'convent secur',
#  'huesatur hscompon',
#  'limit learn',
#  'inquiri middl',
#  'implement variant',
#  'differ measur',
#  'phenomenon first',
#  'comfort vote',
#  'refer parallel',
#  'datapath constraint',
#  'widespread field',
#  'step width',
#  'inevit bring',
#  'test score',
#  'taxonomi frameworkin',
#  'partit techniqu',
#  'specifi motion',
#  'thus bc',
#  'remain achiev',
#  'robot pertin',
#  'vast volum',
#  'framework adopt',
#  'garner increas',
#  'creat aerodynam',
#  'power reductionregist',
#  'capac prevail',
#  'accept altern',
#  'show ajalon',
#  'accuraci usabl',
#  'specif softwar',
#  'consist questionnair',
#  'bandwidth must',
#  'video phase',
#  'mathemat prove',
#  'made tool',
#  'underw primari',
#  'regress approach',
#  'fish pass',
#  'empir relationship',
#  'therefor knowledg',
#  'assess accuraci',
#  'restrict paper',
#  'amplif pair',
#  'maximum permiss',
#  'util enhanc',
#  'asphalt',
#  'adapt learningbas',
#  'verificationcardbas',
#  'unidirect',
#  'tracebas schedul',
#  'rang realtim',
#  'oper certain',
#  'iter current',
#  'consider error',
#  'caus larg',
#  'literatur build',
#  'state strateg',
#  'aescbc mode',
#  'taken various',
#  'frameworksaf',
#  'previous conduct',
#  'two peopl',
#  'shape form',
#  'comput dive',
#  'shown uml',
#  'student one',
#  'fulfil gap',
#  'hale uav',
#  'framework seek',
#  'one scheme',
#  'stretch equibiaxi',
#  'techniqu assur',
#  'estim regard',
#  'compet scheme',
#  'lowerbound known',
#  'yield lmi',
#  'file group',
#  'ergonom survey',
#  'emitt predefin',
#  'regist usag',
#  'visual similar',
#  'intersect framework',
#  'current reconfigur',
#  'olsztyn',
#  'generaliz configur',
#  'evolv search',
#  'protect assembl',
#  'task pour',
#  'embodimentbackground',
#  'capabl format',
#  'opportun recent',
#  'situat rais',
#  'advantag drawback',
#  'sensor addit',
#  'three metaanalys',
#  'evolv gait',
#  'without fulli',
#  'heterogen featur',
#  'map plain',
#  'decept genuin',
#  'posit featur',
#  'encod synthes',
#  'fundament compon',
#  'radio telemetri',
#  'transport frame',
#  'effect adhes',
#  'tree effici',
#  'limitationsenvironment conditionsindooroutdoor',
#  'cpugpu',
#  'ad execut',
#  'quantifi damag',
#  'dairi farm',
#  'substitut rewrit',
#  'fma ue',
#  'cm posit',
#  'increas height',
#  'consid work',
#  'weight median',
#  'wast electr',
#  'outperform metaheurist',
#  'base preliminari',
#  'filter lowend',
#  'space consensus',
#  'longrun',
#  'cracknetii',
#  'minimumspan',
#  'receiv client',
#  'softmax',
#  'resist communic',
#  'model content',
#  'integr fabric',
#  'best work',
#  'rais pair',
#  'capillari control',
#  'month day',
#  'must implement',
#  'despit vertic',
#  'contract project',
#  'risk realiti',
#  'decentr dissemin',
#  'benchmark comparison',
#  'model rule',
#  'larg memori',
#  'approach align',
#  'action itre',
#  'evalu planner',
#  'sphere',
#  'task protect',
#  'failur two',
#  'understand predict',
#  'prove competit',
#  'dataset highest',
#  'top distribut',
#  'analyt workload',
#  'vuetifi manag',
#  'estim curvatur',
#  'naturalanthropogen',
#  'verifi ssa',
#  'neurosurgeon result',
#  'qualiti appear',
#  'break invalid',
#  'lead terabyt',
#  'min per',
#  'great result',
#  'potenti postquantum',
#  'memapelit faster',
#  'differ make',
#  'iot play',
#  'retriev servic',
#  'common appli',
#  'hat',
#  'possibl associ',
#  'cear',
#  'code algorithm',
#  'function certificateless',
#  'decompress relat',
#  'evalu rest',
#  'problem advent',
#  'differenti without',
#  'perimeterfollow',
#  'encrypt optim',
#  'build time',
#  'various entiti',
#  'orim',
#  'demonstr achiev',
#  'marker design',
#  'computationresourc end',
#  'matchingref provid',
#  'effici realize',
#  'implement coursegrain',
#  'method cross',
#  'map geometri',
#  'complet polynomi',
#  'confid lower',
#  'crr preliminari',
#  'knowledg project',
#  'cohort similar',
#  'provid nevertheless',
#  'imag acquir',
#  'affect oliv',
#  'globallevel standard',
#  'specif hybrid',
#  'also record',
#  'size decreas',
#  'tackl stochast',
#  'true robot',
#  'line entri',
#  'parallel requir',
#  'part construct',
#  'denormalis',
#  'therefor queri',
#  'sudoku puzzlecomput',
#  'ecb mode',
#  'target intel',
#  'robot confirm',
#  'updat avoid',
#  'popular sinc',
#  'framework configur',
#  'consid focus',
#  'target mddg',
#  'advertis screen',
#  'prior geometr',
#  'visual learn',
#  'hybrid zero',
#  'demand file',
#  'transform impact',
#  'key idea',
#  'roadblock industri',
#  'fish design',
#  'circuit obtain',
#  'fieldprogrammablegatearray',
#  'categori gift',
#  'lightweight wpt',
#  'place visual',
#  'spanish',
#  'facilit quick',
#  'cumbersom time',
#  'align svmrfegen',
#  'generatorpseudo',
#  'label video',
#  'estim soft',
#  'discuss time',
#  'visual navig',
#  'toggl wire',
#  'instruct quidel',
#  'pkc face',
#  'drowsi improv',
#  'rod slender',
#  'gdl optim',
#  'gnsstesla present',
#  'compil first',
#  'benefici success',
#  'analyz commerci',
#  'nearoptim perform',
#  'contextuallyawar ai',
#  'altitud even',
#  'print materi',
#  'mix nonferr',
#  'similar cephalopod',
#  'compani reli',
#  'trace right',
#  'radialpor',
#  'bitcoin ethereum',
#  'counterpart final',
#  'layer text',
#  'tool machin',
#  'makin',
#  'cycl arm',
#  'inform univers',
#  'partson encrypt',
#  'rich context',
#  'coeffici quantum',
#  'updat neural',
#  'also region',
#  'event start',
#  'featur made',
#  'qcd miniappl',
#  'reconfigur magnet',
#  'multipl except',
#  'lbc one',
#  'reach demonstr',
#  'assumpt discret',
#  'model continu',
#  'present proofofconcept',
#  'avoid unknown',
#  'produc establish',
#  'elimin inputdata',
#  'design deep',
#  'stiff defect',
#  'yolo adopt',
#  'standard petri',
#  'site surveil',
#  'geomorpholog',
#  'generationin',
#  'high primari',
#  'final produc',
#  'compon select',
#  'attempt port',
#  'scan tls',
#  'cell neighbour',
#  'custom mass',
#  'label teacher',
#  'ci particip',
#  'coordin sampl',
#  'tradit educ',
#  'obfusc bflo',
#  'amount pheromon',
#  'evalu ibmq',
#  'final goal',
#  'infti ball',
#  'introduc graph',
#  'allow generat',
#  'written program',
#  'project small',
#  'twofactor',
#  'parallel polynomi',
#  'transplant',
#  'percent accur',
#  'aspect improv',
#  'furthermor follow',
#  'mcellssecond',
#  'lessstructur environ',
#  'one write',
#  'navig comput',
#  'interv analysi',
#  'problem reduc',
#  'analysi larg',
#  'blog webpag',
#  'lack eleg',
#  'insid forest',
#  'run outofthebox',
#  'databas order',
#  'dens popul',
#  'curv finit',
#  'multipl offtheshelf',
#  'recognit difficult',
#  'base indepth',
#  'appl extern',
#  'reconfigur time',
#  'attack error',
#  'fundament paramet',
#  'insert access',
#  'decad area',
#  'lowlevel featur',
#  'novic resolv',
#  'todd',
#  'factor strengthen',
#  'communiti catastroph',
#  'persist complex',
#  'grill chicken',
#  'statcom newtonraphson',
#  'studi contribut',
#  'görüntülerind anomali',
#  'break classic',
#  'solut insid',
#  'inappropri design',
#  'amount confidenti',
#  'includ verifi',
#  'challeng deep',
#  'loss profit',
#  'vulner group',
#  'expert although',
#  'opencl standard',
#  'linear mixedeffect',
#  'perceiv extern',
#  'lopesii',
#  'baselin comparison',
#  'knowledg may',
#  'analog chen',
#  'highaltitud',
#  'comput robot',
#  'shaft',
#  'motiv motion',
#  'algorithm montgomeri',
#  'core often',
#  'elimin inher',
#  'bronchus',
#  'converg singl',
#  'breast thermogramlack',
#  'function powerassist',
#  'consid geometri',
#  'modul need',
#  'regist certif',
#  'qu',
#  'inthewild',
#  'applic predetermin',
#  'activitycentr',
#  'itemset support',
#  'spreadsheet materi',
#  'along pipe',
#  'favor particular',
#  'view satellitederiv',
#  'page control',
#  'index represent',
#  'among softwar',
#  'cabl cabl',
#  'popular motiv',
#  'tabl base',
#  'xml file',
#  'energi convers',
#  'discuss evolv',
#  'fit speed',
#  'input pair',
#  'emg pm',
#  'common share',
#  'storag webvrgisin',
#  'retrospect analyz',
#  'alpha',
#  'meaning high',
#  'avail fieldprogramm',
#  'studi knn',
#  'oper barrier',
#  'result author',
#  'inexpens tool',
#  'labori fabric',
#  'pessimist bound',
#  'longterm memori',
#  'video render',
#  'verifi perform',
#  'recogn four',
#  'preserv safeti',
#  'classif mobil',
#  'embed haskel',
#  'plate translat',
#  'identifi experiment',
#  'necessari enabl',
#  'find effici',
#  'messag encod',
#  'provid weight',
#  'challeng atjnet',
#  'interlay coeffici',
#  'develop pipelin',
#  'depth compil',
#  'filter contribut',
#  'autoindex',
#  'encourag collabor',
#  'fast distribut',
#  'program lexic',
#  'manual generat',
#  'fuzzi clusteringbas',
#  'configur grasp',
#  'nonsignific locat',
#  'best select',
#  'prompt design',
#  'cryptoverif adversari',
#  'asip develop',
#  'improv cach',
#  'hypergraph final',
#  'simplifi network',
#  'target ul',
#  'import construct',
#  'domain normal',
#  'ndvi measur',
#  'model tempor',
#  'scale find',
#  'like india',
#  'sever metric',
#  'apriltag allow',
#  'autonom bit',
#  'demand task',
#  'alongsid ensur',
#  'propuls differ',
#  'transmit hub',
#  'program togeth',
#  'evalu blockchainbas',
#  'forag',
#  'applic anoth',
#  'classif normal',
#  'visual cryptographybas',
#  'tri fill',
#  'layer coher',
#  'design invertandmeasur',
#  'allow realis',
#  'encrypt howev',
#  'advanc asip',
#  'detectioncas',
#  'ddgraph taken',
#  'thing blockchain',
#  'peopl begin',
#  'optic cryptographi',
#  'decommiss establish',
#  'interact tensor',
#  'abil lack',
#  'therebi address',
#  'previous one',
#  'convers relev',
#  'randomnet achiev',
#  'access special',
#  'record modal',
#  'adopt avoid',
#  'queri translat',
#  'darboux frame',
#  'generic stc',
#  'serial strategi',
#  'amplitud chang',
#  'approachth',
#  'usabl surgic',
#  'good correl',
#  'first earli',
#  'key appli',
#  'averag improv',
#  'bug applic',
#  'control exist',
#  'approxim likelihood',
#  'avail attack',
#  'robot promis',
#  'materi ie',
#  'swingcontrol',
#  'provid relev',
#  'pondsurfac aquaticpl',
#  'challeng costeffect',
#  'membran',
#  'autom crack',
#  'complex locomot',
#  'fish import',
#  'telerobot transpar',
#  'bottleneck object',
#  'hysteret behaviour',
#  'thing program',
#  'except one',
#  'investig larg',
#  'success model',
#  'deidentifi dimension',
#  'control chatter',
#  'holzer',
#  'emerg network',
#  'bodi inform',
#  'ant cellular',
#  'upon sixcard',
#  'algorithm describ',
#  'millimetrescal',
#  'cryptographyguarante',
#  'integr screen',
#  'reveal maximum',
#  'cell cell',
#  'quantumresist algorithm',
#  'anomali encrypt',
#  'convers program',
#  'privacypreserv computationhomomorph',
#  'recommend work',
#  'perform session',
#  'iot claim',
#  'ecdsadigit',
#  'safeti map',
#  'encod imag',
#  'howev subject',
#  'pm import',
#  'uninterest may',
#  'reli simultan',
#  'testifi secur',
#  'focus big',
#  'intellig myoelectr',
#  'file small',
#  'till various',
#  'similar enhanc',
#  'accomplish smartphon',
#  'second highest',
#  'sot wide',
#  'local public',
#  'function cryptographi',
#  'growth storag',
#  'timestamp paper',
#  'addedvalu oper',
#  'variabl model',
#  'possibl mean',
#  'subject diagnost',
#  'scienc educ',
#  'local uncertainti',
#  'loss perform',
#  'leach soil',
#  'variat autoencod',
#  'includ accuraci',
#  'relat motion',
#  'trustworthi emerg',
#  'organ fit',
#  'anoth hour',
#  'space automat',
#  'trace map',
#  'act pure',
#  'multidimension format',
#  'format everi',
#  'miss intraor',
#  'error heavili',
#  'depend assum',
#  'manipulandum robot',
#  'localis identif',
#  'provok watermark',
#  'circuit remov',
#  'masq compil',
#  'investig compar',
#  'import peopl',
#  'bvlis develop',
#  'problem surround',
#  'specif decis',
#  'three method',
#  'explor exploit',
#  'sqss protocol',
#  'balanc gait',
#  'also reveal',
#  'suggest user',
#  'network vpsnet',
#  'compil dynam',
#  'sens embodi',
#  'kernelfre',
#  'factor therebi',
#  'nivo break',
#  'function implement',
#  'normalizationw',
#  'call initi',
#  'hybrid integr',
#  'characterist correspond',
#  'focus limit',
#  'decomposit reorgan',
#  'outcom fuglmey',
#  'nerv',
#  'restrain',
#  'risk damag',
#  'aggressionsbit',
#  'featur colour',
#  'includ java',
#  'threshold satisfi',
#  'make visual',
#  'fewshot ai',
#  'feulgen paper',
#  'extend detail',
#  'transform differ',
#  'recognit function',
#  'marker local',
#  'preextract',
#  'highprior',
#  'layout conflict',
#  'task fulli',
#  'precis robust',
#  'understand optim',
#  'shown scale',
#  'manner surgic',
#  'computationfre',
#  'suicid furthermor',
#  'respect branch',
#  'flexibl machin',
#  'crowd countersresourc',
#  'measur coupler',
#  'entrain paradigm',
#  'popul group',
#  'rsa shown',
#  'freetous web',
#  'pearl zipper',
#  'smooth workflow',
#  'often necessari',
#  'amod',
#  'user financi',
#  'name bajardeynardhasanzucca',
#  'number fals',
#  'model indic',
#  'user incap',
#  'produc queri',
#  'target leon',
#  'illicit usag',
#  'forcebas',
#  'complex algorithm',
#  'mortonord',
#  'know input',
#  'process instruct',
#  'learnt descriptor',
#  'sensori predict',
#  'cycl otherwis',
#  'wheel robot',
#  'suscept outsid',
#  'arbitrari ip',
#  'made remot',
#  'case emphasi',
#  'label domain',
#  'increas turbin',
#  'articl assess',
#  'latenc requir',
#  'name mapreduc',
#  'integerssuppos bit',
#  'materi due',
#  'group inform',
#  'question question',
#  'servic precis',
#  'includ latticebas',
#  'first extens',
#  'research pam',
#  'inform machineread',
#  'inspect search',
#  'followup demograph',
#  'machin mitig',
#  'novel pixelresolut',
#  'stimul fingertip',
#  'would decrypt',
#  'human caption',
#  'insid memori',
#  'easili identifi',
#  'incorrect target',
#  'languag integr',
#  'origin signal',
#  'due emerg',
#  'compar favor',
#  'filter except',
#  'theori take',
#  'produc answer',
#  'light affect',
#  'studi comprehens',
#  'announc winner',
#  'two extrem',
#  'metric steadyst',
#  'final simul',
#  'sustain observatori',
#  'method templat',
#  'summar common',
#  'evalu strategi',
#  'semin exist',
#  'framework opensourc',
#  'robot complex',
#  'paper kind',
#  'keygener scheme',
#  'stabil auv',
#  'first principl',
#  'moderatesever',
#  'symbol resourc',
#  'kib ieee',
#  'order everi',
#  'misus digit',
#  'spatial vector',
#  'condit satisfi',
#  'normal defect',
#  'reimplement',
#  'ciphersin paper',
#  'eg energi',
#  'caus bodybrain',
#  'outcom quantit',
#  'host ionic',
#  'orthogon tissu',
#  'procedur could',
#  'meet industri',
#  'area make',
#  'construct ibkem',
#  'china turkey',
#  'analiziattent',
#  'ieee bus',
#  'addit train',
#  'offload unavail',
#  'comparison chaotic',
#  'util zynq',
#  'limit usag',
#  'behavior final',
#  'status aquat',
#  'dmd mode',
#  'radiat hotspot',
#  'predict powereffici',
#  'hide encrypt',
#  'distort higher',
#  'programsin',
#  'extractionbas method',
#  'hysteresi preslid',
#  'openloop',
#  'transmiss key',
#  'person lowshot',
#  'thingsth emerg',
#  'usabl assess',
#  'compil explain',
#  'assistanceindividu tetraplegia',
#  'rom estim',
#  'hydraul press',
#  'maximum intrud',
#  'measur electromyographi',
#  'stiffen',
#  'represent surgic',
#  'shown implement',
#  'privaci polici',
#  'set size',
#  'myotomi poem',
#  ...}

# %%
# Calculate NMI
clustering = KMeans(n_clusters=5, n_init=10, random_state=2).fit(x)

labels = clustering.labels_

normalized_mutual_info_score(labels, df['class'])
# Out:
# 0.7721250155982129

# %%
# LSA
lsaApplied = TruncatedSVD(n_components=100, random_state=5).fit_transform(x)

# %%
# Spectral clustering with cosine distance. Laplacian ?
clustering = SpectralClustering(n_clusters=5, affinity='cosine', random_state=2, assign_labels='discretize', ).fit(lsaApplied)

labels = clustering.labels_

normalized_mutual_info_score(labels, df['class'], )
# Out:
# 0.8113642267466998

# %%
df["clusteringLabel"] = labels

# %%
cluster0 = df[df['clusteringLabel'] == 0]
cluster1 = df[df['clusteringLabel'] == 1]
cluster2 = df[df['clusteringLabel'] == 2]
cluster3 = df[df['clusteringLabel'] == 3]
cluster4 = df[df['clusteringLabel'] == 4]

c0 = countAndSort(cluster0['preprocessed'])[0:30]
c1 = countAndSort(cluster1['preprocessed'])[0:30]
c2 = countAndSort(cluster2['preprocessed'])[0:30]
c3 = countAndSort(cluster3['preprocessed'])[0:30]
c4 = countAndSort(cluster4['preprocessed'])[0:30]

print(
  "cluster0:\n", c0, "\n------------------------------------------\n",
  "cluster1:\n", c1, "\n------------------------------------------\n",
  "cluster2:\n", c2, "\n------------------------------------------\n",
  "cluster3:\n", c3, "\n------------------------------------------\n",
  "cluster4:\n", c4, "\n------------------------------------------\n")

# cluster0 databases
# cluster1 datascience(datamining, machinelearning)???
# cluster2 information security
# cluster3 robotics
# cluster4 programming
# Out:
# cluster0:
#  [('use', 757), ('imag', 644), ('method', 608), ('propos', 505), ('detect', 481), ('model', 480), ('system', 430), ('comput', 394), ('perform', 353), ('result', 324), ('network', 323), ('learn', 317), ('data', 308), ('vision', 307), ('base', 297), ('algorithm', 296), ('approach', 267), ('object', 264), ('featur', 245), ('dataset', 243), ('deep', 233), ('accuraci', 227), ('paper', 227), ('differ', 216), ('studi', 213), ('applic', 211), ('improv', 202), ('develop', 195), ('research', 195), ('process', 192)]
# ------------------------------------------
#  cluster1:
#  [('compil', 565), ('program', 369), ('use', 348), ('comput', 275), ('code', 253), ('languag', 224), ('optim', 206), ('system', 205), ('implement', 179), ('applic', 177), ('paper', 170), ('algorithm', 161), ('design', 154), ('perform', 151), ('memori', 149), ('graph', 145), ('parallel', 145), ('present', 137), ('time', 135), ('approach', 133), ('base', 131), ('oper', 129), ('data', 127), ('techniqu', 124), ('model', 123), ('result', 119), ('transform', 118), ('execut', 116), ('quantum', 115), ('develop', 114)]
# ------------------------------------------
#  cluster2:
#  [('databas', 640), ('data', 593), ('relat', 348), ('queri', 273), ('use', 272), ('system', 266), ('model', 192), ('inform', 175), ('approach', 157), ('propos', 138), ('process', 132), ('paper', 113), ('manag', 104), ('develop', 102), ('base', 101), ('perform', 98), ('result', 98), ('applic', 95), ('ontolog', 94), ('sql', 92), ('present', 91), ('design', 89), ('method', 84), ('implement', 81), ('integr', 81), ('differ', 80), ('user', 80), ('languag', 79), ('store', 79), ('provid', 74)]
# ------------------------------------------
#  cluster3:
#  [('secur', 659), ('use', 380), ('propos', 360), ('scheme', 331), ('data', 297), ('encrypt', 290), ('key', 276), ('attack', 225), ('comput', 225), ('protocol', 224), ('cryptographi', 220), ('base', 214), ('quantum', 214), ('system', 214), ('algorithm', 205), ('implement', 178), ('authent', 142), ('provid', 142), ('paper', 140), ('effici', 138), ('iot', 138), ('perform', 133), ('applic', 132), ('design', 132), ('imag', 127), ('cloud', 119), ('model', 113), ('network', 111), ('communic', 109), ('devic', 106)]
# ------------------------------------------
#  cluster4:
#  [('robot', 731), ('control', 313), ('use', 267), ('system', 253), ('perform', 156), ('model', 153), ('result', 136), ('task', 134), ('propos', 130), ('develop', 124), ('design', 118), ('learn', 114), ('present', 107), ('soft', 104), ('approach', 103), ('environ', 102), ('simul', 102), ('studi', 98), ('differ', 95), ('method', 92), ('forc', 89), ('improv', 87), ('work', 87), ('base', 83), ('show', 82), ('effect', 81), ('provid', 81), ('experi', 80), ('demonstr', 79), ('sensor', 78)]
# ------------------------------------------
